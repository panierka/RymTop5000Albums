# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.set(rc={'figure.figsize':(12,10)})

# %%
df = pd.read_csv('data/rym_clean1.csv', index_col=0)
df
# Out:
#       position                       release_name          artist_name  \
# 1            1                        OK Computer            Radiohead
# 2            2                              Kid A            Radiohead
# 3            3          The Dark Side of the Moon           Pink Floyd
# 4            4                           Loveless  My Bloody Valentine
# 5            5  My Beautiful Dark Twisted Fantasy           Kanye West
# ...        ...                                ...                  ...
# 4996      4996                              Copia              Eluvium
# 4997      4997   Let Mortal Heroes Sing Your Fame            Summoning
# 4998      4998                     Dangerous Days          Perturbator
# 4999      4999                     Third Ear Band       Third Ear Band
# 5000      5000                          The Album                 ABBA
#
#      release_date release_type  \
# 1      1997-06-16        album
# 2      2000-10-03        album
# 3      1973-03-23        album
# 4      1991-11-11        album
# 5      2010-11-22        album
# ...           ...          ...
# 4996   2007-02-20        album
# 4997   2001-10-31        album
# 4998   2014-06-17        album
# 4999   1970-06-01        album
# 5000   1977-12-12        album
#
#                                       primary_genres  \
# 1                         Alternative Rock, Art Rock
# 2            Art Rock, Experimental Rock, Electronic
# 3                         Art Rock, Progressive Rock
# 4                                Shoegaze, Noise Pop
# 5                                   Pop Rap, Hip Hop
# ...                                              ...
# 4996                                         Ambient
# 4997  Atmospheric Black Metal, Symphonic Black Metal
# 4998              Darksynth, Horror Synth, Synthwave
# 4999                     Progressive Folk, Free Folk
# 5000                            Pop, Progressive Pop
#
#                        secondary_genres  \
# 1                                   NaN
# 2              Ambient, Electronic, IDM
# 3          Psychedelic Rock, Space Rock
# 4            Dream Pop, Neo-Psychedelia
# 5                               Art Pop
# ...                                 ...
# 4996  Modern Classical, Post-Minimalism
# 4997                      Dungeon Synth
# 4998                 Electro-Industrial
# 4999          Drone, Free Improvisation
# 5000                  Europop, Pop Rock
#
#                                             descriptors  avg_rating  \
# 1     melancholic, anxious, futuristic, malevocals, ...        4.24
# 2     cold, melancholic, futuristic, anxious, atmosp...        4.23
# 3     philosophical, atmospheric, introspective, exi...        4.21
# 4     noisy, ethereal, atmospheric, romantic, love, ...        4.24
# 5     epic, boastful, passionate, sampling, hedonist...        4.09
# ...                                                 ...         ...
# 4996  instrumental, atmospheric, bittersweet, sentim...        3.44
# 4997  fantasy, epic, triumphant, melodic, atmospheri...        3.73
# 4998  futuristic, ominous, sciencefiction, atmospher...        3.50
# 4999  instrumental, ritualistic, hypnotic, atmospher...        3.63
# 5000  femalevocals, melodic, playful, uplifting, rom...        3.55
#
#       rating_count  review_count
# 1            74027          1541
# 2            61658           751
# 3            60192          1557
# 4            53174          1264
# 5            52149           638
# ...            ...           ...
# 4996          2171            63
# 4997          2170            20
# 4998          2170            21
# 4999          2169            39
# 5000          2169            51
#
# [5000 rows x 11 columns]

# %%
(df.index == df['position']).all()
# Out:
# True

# %%
df.drop('position', axis=1, inplace=True)
df
# Out:
#                            release_name          artist_name release_date  \
# 1                           OK Computer            Radiohead   1997-06-16
# 2                                 Kid A            Radiohead   2000-10-03
# 3             The Dark Side of the Moon           Pink Floyd   1973-03-23
# 4                              Loveless  My Bloody Valentine   1991-11-11
# 5     My Beautiful Dark Twisted Fantasy           Kanye West   2010-11-22
# ...                                 ...                  ...          ...
# 4996                              Copia              Eluvium   2007-02-20
# 4997   Let Mortal Heroes Sing Your Fame            Summoning   2001-10-31
# 4998                     Dangerous Days          Perturbator   2014-06-17
# 4999                     Third Ear Band       Third Ear Band   1970-06-01
# 5000                          The Album                 ABBA   1977-12-12
#
#      release_type                                  primary_genres  \
# 1           album                      Alternative Rock, Art Rock
# 2           album         Art Rock, Experimental Rock, Electronic
# 3           album                      Art Rock, Progressive Rock
# 4           album                             Shoegaze, Noise Pop
# 5           album                                Pop Rap, Hip Hop
# ...           ...                                             ...
# 4996        album                                         Ambient
# 4997        album  Atmospheric Black Metal, Symphonic Black Metal
# 4998        album              Darksynth, Horror Synth, Synthwave
# 4999        album                     Progressive Folk, Free Folk
# 5000        album                            Pop, Progressive Pop
#
#                        secondary_genres  \
# 1                                   NaN
# 2              Ambient, Electronic, IDM
# 3          Psychedelic Rock, Space Rock
# 4            Dream Pop, Neo-Psychedelia
# 5                               Art Pop
# ...                                 ...
# 4996  Modern Classical, Post-Minimalism
# 4997                      Dungeon Synth
# 4998                 Electro-Industrial
# 4999          Drone, Free Improvisation
# 5000                  Europop, Pop Rock
#
#                                             descriptors  avg_rating  \
# 1     melancholic, anxious, futuristic, malevocals, ...        4.24
# 2     cold, melancholic, futuristic, anxious, atmosp...        4.23
# 3     philosophical, atmospheric, introspective, exi...        4.21
# 4     noisy, ethereal, atmospheric, romantic, love, ...        4.24
# 5     epic, boastful, passionate, sampling, hedonist...        4.09
# ...                                                 ...         ...
# 4996  instrumental, atmospheric, bittersweet, sentim...        3.44
# 4997  fantasy, epic, triumphant, melodic, atmospheri...        3.73
# 4998  futuristic, ominous, sciencefiction, atmospher...        3.50
# 4999  instrumental, ritualistic, hypnotic, atmospher...        3.63
# 5000  femalevocals, melodic, playful, uplifting, rom...        3.55
#
#       rating_count  review_count
# 1            74027          1541
# 2            61658           751
# 3            60192          1557
# 4            53174          1264
# 5            52149           638
# ...            ...           ...
# 4996          2171            63
# 4997          2170            20
# 4998          2170            21
# 4999          2169            39
# 5000          2169            51
#
# [5000 rows x 10 columns]

# %%
df.dtypes
# Out:
# release_name         object
# artist_name          object
# release_date         object
# release_type         object
# primary_genres       object
# secondary_genres     object
# descriptors          object
# avg_rating          float64
# rating_count          int64
# review_count          int64
# dtype: object

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
sns.histplot(df, x='avg_rating', kde=True)
plt.show()

# %%
sns.boxplot(x=df['avg_rating'])
plt.show()

# %%
df['avg_rating'].describe()
# Out:
# count    5000.000000
# mean        3.540424
# std         0.374449
# min         0.620000
# 25%         3.410000
# 50%         3.620000
# 75%         3.770000
# max         4.340000
# Name: avg_rating, dtype: float64

# %%
df.head(10)
# Out:
#                          release_name          artist_name release_date  \
# 1                         OK Computer            Radiohead   1997-06-16
# 2                               Kid A            Radiohead   2000-10-03
# 3           The Dark Side of the Moon           Pink Floyd   1973-03-23
# 4                            Loveless  My Bloody Valentine   1991-11-11
# 5   My Beautiful Dark Twisted Fantasy           Kanye West   2010-11-22
# 6                         In Rainbows            Radiohead   2007-10-10
# 7                  Wish You Were Here           Pink Floyd   1975-09-12
# 8       In the Aeroplane Over the Sea   Neutral Milk Hotel   1998-02-10
# 9                           The Bends            Radiohead   1995-03-13
# 10                To Pimp a Butterfly       Kendrick Lamar   2015-03-15
#
#    release_type                                   primary_genres  \
# 1         album                       Alternative Rock, Art Rock
# 2         album          Art Rock, Experimental Rock, Electronic
# 3         album                       Art Rock, Progressive Rock
# 4         album                              Shoegaze, Noise Pop
# 5         album                                 Pop Rap, Hip Hop
# 6         album                       Art Rock, Alternative Rock
# 7         album                       Progressive Rock, Art Rock
# 8         album                           Indie Folk, Indie Rock
# 9         album                                 Alternative Rock
# 10        album  Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
#
#                                      secondary_genres  \
# 1                                                 NaN
# 2                            Ambient, Electronic, IDM
# 3                        Psychedelic Rock, Space Rock
# 4                          Dream Pop, Neo-Psychedelia
# 5                                             Art Pop
# 6                      Electronic, Dream Pop, Art Pop
# 7                        Space Rock, Psychedelic Rock
# 8   Psychedelic Folk, Singer-Songwriter, Lo-Fi/Sla...
# 9                                             Britpop
# 10  Political Hip Hop, Neo-Soul, Funk, Poetry, Exp...
#
#                                           descriptors  avg_rating  \
# 1   melancholic, anxious, futuristic, malevocals, ...        4.24
# 2   cold, melancholic, futuristic, anxious, atmosp...        4.23
# 3   philosophical, atmospheric, introspective, exi...        4.21
# 4   noisy, ethereal, atmospheric, romantic, love, ...        4.24
# 5   epic, boastful, passionate, sampling, hedonist...        4.09
# 6   lush, malevocals, introspective, melancholic, ...        4.20
# 7   melancholic, atmospheric, progressive, malevoc...        4.30
# 8   passionate, poetic, death, cryptic, surreal, b...        4.09
# 9   melancholic, lonely, melodic, anxious, introsp...        3.84
# 10  political, conscious, poetic, conceptalbum, pr...        4.30
#
#     rating_count  review_count
# 1          74027          1541
# 2          61658           751
# 3          60192          1557
# 4          53174          1264
# 5          52149           638
# 6          51335           752
# 7          51246          1006
# 8          50353           983
# 9          48578           798
# 10         47821           415

# %%
df.tail(10)
# Out:
#                           release_name     artist_name release_date  \
# 4991                        Tigers Jaw      Tigers Jaw   2008-01-01
# 4992     Mirror Might Steal Your Charm      The Garden   2018-03-30
# 4993             The Life of Pi'erre 4  Pi'erre Bourne   2019-06-21
# 4994                    Johnny the Fox      Thin Lizzy   1976-10-01
# 4995                Battalions of Fear  Blind Guardian   1988-05-18
# 4996                             Copia         Eluvium   2007-02-20
# 4997  Let Mortal Heroes Sing Your Fame       Summoning   2001-10-31
# 4998                    Dangerous Days     Perturbator   2014-06-17
# 4999                    Third Ear Band  Third Ear Band   1970-06-01
# 5000                         The Album            ABBA   1977-12-12
#
#      release_type                                  primary_genres  \
# 4991        album                                 Emo, Indie Rock
# 4992        album                     Experimental Rock, Art Punk
# 4993        album                                   Pop Rap, Trap
# 4994        album                                       Hard Rock
# 4995        album                        Speed Metal, Power Metal
# 4996        album                                         Ambient
# 4997        album  Atmospheric Black Metal, Symphonic Black Metal
# 4998        album              Darksynth, Horror Synth, Synthwave
# 4999        album                     Progressive Folk, Free Folk
# 5000        album                            Pop, Progressive Pop
#
#                                        secondary_genres  \
# 4991                                  Pop Punk, Emo-Pop
# 4992  Experimental Hip Hop, Post-Punk, Zolo, Synth Punk
# 4993                  Alternative R&B, Cloud Rap, Plugg
# 4994                                          Funk Rock
# 4995                                                NaN
# 4996                  Modern Classical, Post-Minimalism
# 4997                                      Dungeon Synth
# 4998                                 Electro-Industrial
# 4999                          Drone, Free Improvisation
# 5000                                  Europop, Pop Rock
#
#                                             descriptors  avg_rating  \
# 4991  energetic, breakup, passionate, malevocals, an...        3.54
# 4992  eclectic, quirky, humorous, malevocals, playfu...        3.33
# 4993  psychedelic, repetitive, love, atmospheric, wa...        3.12
# 4994  melodic, energetic, malevocals, conceptalbum, ...        3.73
# 4995  fantasy, energetic, melodic, malevocals, anthe...        3.38
# 4996  instrumental, atmospheric, bittersweet, sentim...        3.44
# 4997  fantasy, epic, triumphant, melodic, atmospheri...        3.73
# 4998  futuristic, ominous, sciencefiction, atmospher...        3.50
# 4999  instrumental, ritualistic, hypnotic, atmospher...        3.63
# 5000  femalevocals, melodic, playful, uplifting, rom...        3.55
#
#       rating_count  review_count
# 4991          2174            14
# 4992          2173            24
# 4993          2173            24
# 4994          2172            63
# 4995          2172            48
# 4996          2171            63
# 4997          2170            20
# 4998          2170            21
# 4999          2169            39
# 5000          2169            51

# %%
sns.scatterplot(x=df.index, y=df['avg_rating'])
plt.show()

# %%
sns.histplot(data=df, x='release_date')
plt.show()

# %%
df.groupby(df['release_date'].map(lambda x: x.year)).size().sort_values(ascending=False).head(5)
# Out:
# release_date
# 2018    150
# 2020    145
# 2019    144
# 2017    140
# 2005    128
# dtype: int64

# %%
(df['primary_genres'].isna()).sum()
# Out:
# 1

# %%
(df['secondary_genres'].isna()).sum()
# Out:
# 495

# %%
df[df['primary_genres'].isna() & df['secondary_genres'].isna()]
# Out:
# Empty DataFrame
# Columns: [release_name, artist_name, release_date, release_type, primary_genres, secondary_genres, descriptors, avg_rating, rating_count, review_count]
# Index: []

# %%
df.fillna('', inplace=True)

# %%
df_g = df.copy()

def combine_genre_columns(row):
    primary = row['primary_genres']
    secondary = row['secondary_genres']
    seps = (',', ', ')

    def split_by_all(s: str):
        for sep in seps[1:]:
            s = s.replace(sep, seps[0])
        return s.split(seps[0])

    if primary == '':
        return split_by_all(secondary)

    if secondary == '':
        return split_by_all(primary)

    return split_by_all(primary) + split_by_all(secondary)

df_g.insert(loc=4, column='genres', value=df_g.apply(combine_genre_columns, axis=1))
df_g.drop(columns=['primary_genres', 'secondary_genres'], inplace=True)
df_g['genres'] = df_g['genres'].values.tolist()
genres = pd.DataFrame(df_g['genres'].explode())
genres.columns = ['genre']
genres.reset_index(inplace=True)
genres
# Out:
#        index               genre
# 0          1    Alternative Rock
# 1          1            Art Rock
# 2          2            Art Rock
# 3          2   Experimental Rock
# 4          2          Electronic
# ...      ...                 ...
# 20264   4999  Free Improvisation
# 20265   5000                 Pop
# 20266   5000     Progressive Pop
# 20267   5000             Europop
# 20268   5000            Pop Rock
#
# [20269 rows x 2 columns]

# %%
def find_genre(genre):
    mask = np.zeros(len(df)).astype(bool)
    indices = genres.loc[genres['genre'] == genre, 'index'].apply(lambda x: x - 1).tolist()
    mask[indices] = True
    return mask

preview_columns = ['release_name', 'artist_name', 'avg_rating', 'genres']

def show_genre(genre):
    return df_g.loc[find_genre(genre), preview_columns].sort_values('avg_rating', ascending=False)

show_genre('Neofolk')
# Out:
#                                   release_name          artist_name  \
# 245                                   The Seer                Swans
# 540                      The Great Annihilator                Swans
# 450     White Light From the Mouth of Infinity                Swans
# 506                                 The Mantle             Agalloch
# 636                            The Glowing Man                Swans
# 554                            Children of God                Swans
# 1936                      Thunder Perfect Mind           Current 93
# 4344           Of Ruine or Some Blazing Starre           Current 93
# 1645              All the Pretty Little Horses           Current 93
# 3446                        Flowers From Exile                 ROME
# 2010                           How I Loved You  The Angels of Light
# 1577                                     Abyss        Chelsea Wolfe
# 1681  But, What Ends When the Symbols Shatter?        Death in June
# 4080                                     Nada!        Death in June
# 1002                          leaving meaning.                Swans
# 4878               The Light Is Leaving Us All           Current 93
# 1737                              Love of Life                Swans
# 4407                         Birth of Violence        Chelsea Wolfe
# 2004                         The Burning World                Swans
#
#       avg_rating                                             genres
# 245         3.94  [Experimental Rock, Post-Rock, Drone, Noise Ro...
# 540         3.86  [Post-Punk, Experimental Rock, Gothic Rock, No...
# 450         3.85              [Gothic Rock, Neofolk, Ethereal Wave]
# 506         3.84  [Post-Metal, Folk Metal, Dark Folk, Post-Rock,...
# 636         3.83  [Post-Rock, Experimental Rock, Noise Rock, Dro...
# 554         3.82  [Experimental Rock, Post-Punk, Gothic Rock, In...
# 1936        3.78  [Neofolk, Psychedelic Folk, English Folk Music...
# 4344        3.77                      [Neofolk, Poetry, Avant-Folk]
# 1645        3.73                [Neofolk, Drone, Poetry, Lullabies]
# 3446        3.73                      [Neofolk, Martial Industrial]
# 2010        3.72  [Folk Rock, Gothic Country, Avant-Folk, Post-R...
# 1577        3.68  [Darkwave, Gothic Rock, Ethereal Wave, Doom Me...
# 1681        3.62                                          [Neofolk]
# 4080        3.57  [Darkwave, Post-Punk, Neofolk, Electro-Industr...
# 1002        3.54  [Post-Rock, Experimental Rock, Avant-Folk, Got...
# 4878        3.52  [Neofolk, Avant-Folk, Poetry, Psychedelic Folk...
# 1737        3.41   [Gothic Rock, Post-Punk, Neofolk, Ethereal Wave]
# 4407        3.31  [Singer-Songwriter, Gothic Country, Dark Folk,...
# 2004        3.11  [Neofolk, Gothic Rock, Gothic Country, Gothic ...

# %%
genre_counts = pd.DataFrame(genres.groupby('genre').size())
genre_counts.reset_index(inplace=True)
genre_counts.columns = ['genre', 'count']
genre_counts
# Out:
#                 genre  count
# 0              16-bit      1
# 1              2-Step      6
# 2               2Tone      5
# 3                 AOR     23
# 4    Abstract Hip Hop    116
# ..                ...    ...
# 731        Yacht Rock      3
# 732             Yé-yé      1
# 733             Zeuhl      5
# 734              Zolo     23
# 735            Zydeco      2
#
# [736 rows x 2 columns]

# %%
genres_pop_rank = genre_counts.sort_values('count', ascending=False).reset_index(drop=True)
genres_pop_rank.index += 1
genres_pop_rank.head(30)
# Out:
#                    genre  count
# 1      Singer-Songwriter    425
# 2       Alternative Rock    425
# 3               Pop Rock    373
# 4                Art Pop    357
# 5             Indie Rock    337
# 6        Neo-Psychedelia    322
# 7               Art Rock    313
# 8              Hard Rock    307
# 9       Progressive Rock    277
# 10     Experimental Rock    269
# 11             Dream Pop    267
# 12             Post-Punk    266
# 13      Psychedelic Rock    259
# 14              Synthpop    249
# 15               Ambient    237
# 16             Indie Pop    220
# 17            Noise Rock    219
# 18               Pop Rap    212
# 19            Blues Rock    198
# 20       Psychedelic Pop    194
# 21     Conscious Hip Hop    192
# 22             Post-Rock    191
# 23             Folk Rock    189
# 24         Post-Hardcore    177
# 25           Heavy Metal    176
# 26           Ambient Pop    168
# 27  Experimental Hip Hop    166
# 28           Chamber Pop    165
# 29     Progressive Metal    162
# 30    East Coast Hip Hop    162

# %%
unique_genres = genres_pop_rank[genres_pop_rank['count'] == 1]
len(unique_genres)
# Out:
# 156

# %%
unique_genres.sample(6)
# Out:
#                         genre  count
# 704       Neue Deutsche Welle      1
# 625             Expressionism      1
# 674           Halloween Music      1
# 651                  Ballroom      1
# 582                    Tejano      1
# 663  Carnatic Classical Music      1

# %%
len(genres_pop_rank)
# Out:
# 736

# %%
tmp = df_g.copy()
tmp = tmp.explode('genres')
tmp['release_decade'] = tmp['release_date'].map(lambda x: x.year // 10 * 10)
d_genre_counts = tmp.groupby(['release_decade', 'genres']).size()
d_genre_counts
# Out:
# release_decade  genres
# 1950            Avant-Garde Jazz      3
#                 Baroque Music         1
#                 Bebop                 1
#                 Big Band              2
#                 Bossanova             1
#                                      ..
# 2020            West Coast Hip Hop    8
#                 Witch House           2
#                 Wonky                 2
#                 Zeuhl                 1
#                 Zolo                  1
# Length: 2236, dtype: int64

# %%
decades = d_genre_counts.index.get_level_values(0).unique().tolist()
decades
# Out:
# [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]

# %%
from IPython.core.display_functions import display

for i, decade in enumerate(decades):
    tmp = d_genre_counts[decade].sort_values(ascending=False)
    total = tmp.sum()
    n = 10
    other = tmp.tail(-n).sum()
    tmp = tmp.head(n)
    tmp.loc['Pozostałe'] = other
    tmp.plot.pie(title=decade, ylabel='', autopct='%1.1f%%')
    plt.show()
    top_genre = tmp.head(1).index[0]
    display(
        df_g.loc[
            find_genre(top_genre)
            & (df_g['release_date'].map(lambda x: x.year // 10 * 10) == decade),
            ['artist_name', 'release_name', 'avg_rating', 'release_date']
        ].sort_values('avg_rating', ascending=False).head(3)
    )
# Out:
#                              artist_name  \
# 460                       Charles Mingus
# 1054  Art Blakey and The Jazz Messengers
# 462                        John Coltrane
#
#                                       release_name  avg_rating release_date
# 460                                   Mingus Ah Um        4.09   1959-09-14
# 1054  Art Blakey and The Jazz Messengers [Moanin']        4.05   1959-01-01
# 462                                     Blue Train        4.02   1958-01-01
#                       artist_name                      release_name  \
# 12                   King Crimson  In the Court of the Crimson King
# 11  The Velvet Underground & Nico     The Velvet Underground & Nico
# 16                    The Beatles                          Revolver
#
#     avg_rating release_date
# 12        4.30   1969-10-10
# 11        4.23   1967-03-12
# 16        4.23   1966-08-05
#       artist_name               release_name  avg_rating release_date
# 7      Pink Floyd         Wish You Were Here        4.30   1975-09-12
# 101  King Crimson                        Red        4.22   1974-10-06
# 3      Pink Floyd  The Dark Side of the Moon        4.21   1973-03-23
#       artist_name       release_name  avg_rating release_date
# 26  Talking Heads    Remain in Light        4.25   1980-10-08
# 56       The Cure     Disintegration        4.18   1989-05-02
# 32     The Smiths  The Queen Is Dead        4.13   1986-06-16
#            artist_name   release_name  avg_rating release_date
# 1            Radiohead    OK Computer        4.24   1997-06-16
# 130       Jeff Buckley          Grace        3.98   1994-08-23
# 111  Smashing Pumpkins  Siamese Dream        3.96   1993-07-26
#               artist_name   release_name  avg_rating release_date
# 6               Radiohead    In Rainbows        4.20   2007-10-10
# 1546  山岡晃 [Akira Yamaoka]  Silent Hill 2        4.11   2001-10-03
# 813                  Ween         Quebec        3.96   2003-08-05
#     artist_name                       release_name  avg_rating release_date
# 5    Kanye West  My Beautiful Dark Twisted Fantasy        4.09   2010-11-22
# 46  Frank Ocean                             Blonde        4.06   2016-08-20
# 55    Radiohead                 A Moon Shaped Pool        3.90   2016-05-08
#           artist_name          release_name  avg_rating release_date
# 4815       RXK Nephew  Slitherman Activated        3.55   2021-05-28
# 2768              Nas     King’s Disease II        3.53   2021-08-06
# 778   Earl Sweatshirt                 Sick!        3.52   2022-01-14

# %%
def show_genres_popularity_rise(genre_list):
    tmp = df_g.copy()
    tmp = tmp.explode('genres')
    tmp['release_year'] = tmp['release_date'].map(lambda x: x.year)

    genre_popularity_in_time = pd.DataFrame(tmp.groupby(['genres', 'release_year']).size())
    genre_popularity_in_time.columns = ['count']
    genre_popularity_in_time = genre_popularity_in_time.loc[genre_list].unstack(0)
    genre_popularity_in_time.fillna(0, inplace=True)
    genre_popularity_in_time.columns = genre_popularity_in_time.columns.get_level_values(1)
    genre_popularity_in_time.index = genre_popularity_in_time.index.sort_values()
    genre_popularity_in_time = genre_popularity_in_time.astype(int)
    genre_popularity_in_time = genre_popularity_in_time.cumsum()
    genre_popularity_in_time.plot.line(legend=True, figsize=(20, 10), style='o-')
    plt.show()

# %%
top10_genres = genres_pop_rank.head(10)['genre'].tolist()
show_genres_popularity_rise(top10_genres)

# %%
show_genres_popularity_rise(['Post-Punk', 'Space Rock', 'Synthpop', 'Dream Pop', 'Baroque Pop'])

# %%
df_g.loc[df_g['avg_rating'] <= df_g['avg_rating'].quantile(0.01), preview_columns + ['release_date']]
# Out:
#                            release_name                artist_name  \
# 391                           St. Anger                  Metallica
# 862                                  17               XXXTentacion
# 922                             Revival                     Eminem
# 942                            Scorpion                      Drake
# 945                            Kamikaze                     Eminem
# 1119                Certified Lover Boy                      Drake
# 1141                                  ?               XXXTentacion
# 1280                               Lulu       Lou Reed & Metallica
# 1427            Music to Be Murdered By                     Eminem
# 1463                        The Big Day          Chance the Rapper
# 1549                           Raditude                     Weezer
# 1795           Speedin' Bullet 2 Heaven                   Kid Cudi
# 1922                     Father of All…                  Green Day
# 1924                Weezer [Teal Album]                     Weezer
# 2201               Weezer [Black Album]                     Weezer
# 2219                              Skins               XXXTentacion
# 2415                         Culture II                      Migos
# 2436                   Pacific Daydream                     Weezer
# 2825                         ÷ (Divide)                 Ed Sheeran
# 2843                     Total Xanarchy                    Lil Xan
# 3112                              ¡Uno!                  Green Day
# 3146                 Angelic 2 the Core              Corey Feldman
# 3196                          Everybody                      Logic
# 3210                     One More Light                Linkin Park
# 3326                    Harverd Dropout                   Lil Pump
# 3339                            Squeeze     The Velvet Underground
# 3395        Nostalgia Critic's The Wall  Rob Scallon & Doug Walker
# 3415                          Dummy Boy                    6ix9ine
# 3582    Confessions of a Dangerous Mind                      Logic
# 3655        Anthem of the Peaceful Army            Greta Van Fleet
# 3699                        Supermarket                      Logic
# 3705                     Silver Side Up                 Nickelback
# 3757                              ¡Dos!                  Green Day
# 3798                             Evolve            Imagine Dragons
# 3977                       Cut the Crap                  The Clash
# 3984                              ¡Tré!                  Green Day
# 4039                        Nastradamus                        Nas
# 4077              All the Right Reasons                 Nickelback
# 4139                         The E.N.D.        The Black Eyed Peas
# 4169        Miley Cyrus & Her Dead Petz                Miley Cyrus
# 4254  American Beauty / American Psycho               Fall Out Boy
# 4412                   Results May Vary                Limp Bizkit
# 4488                     Super Collider                   Megadeth
# 4549                  Bad Vibes Forever               XXXTentacion
# 4611                            Origins            Imagine Dragons
# 4637                   Teenage Emotions                 Lil Yachty
# 4764                          M A N I A               Fall Out Boy
# 4765                Pray for the Wicked        Panic! at the Disco
# 4832               Music of the Spheres                   Coldplay
# 4895               The Path of Totality                       Korn
# 4947               Death to False Metal                     Weezer
#
#       avg_rating                                             genres  \
# 391         1.82        [Alternative Metal, Nu Metal, Thrash Metal]
# 862         1.96  [Alternative R&B, Emo Rap, Singer-Songwriter, ...
# 922         1.03  [Pop Rap, Political Hip Hop, Rap Rock, Conscio...
# 942         1.81  [Pop Rap, Contemporary R&B, Trap, Alternative ...
# 945         1.92                  [Trap, Pop Rap, Hardcore Hip Hop]
# 1119        1.81  [Pop Rap, Trap, Alternative R&B, Chipmunk Soul...
# 1141        2.05  [Emo Rap, Alternative R&B, Trap, Cloud Rap, Si...
# 1280        1.93  [Avant-Garde Metal, Heavy Metal, Spoken Word, ...
# 1427        1.97  [Pop Rap, Trap, Hardcore Hip Hop, Horrorcore, ...
# 1463        1.28  [Pop Rap, Contemporary R&B, Conscious Hip Hop,...
# 1549        1.58                              [Power Pop, Pop Rock]
# 1795        1.55  [Alternative Rock, Grunge, Punk Rock, Acoustic...
# 1922        1.34  [Garage Rock Revival, Pop Rock, Power Pop, Alt...
# 1924        2.12  [Pop Rock, Power Pop, Synthpop, Alternative Rock]
# 2201        2.10         [Pop Rock, Alt-Pop, Electropop, Power Pop]
# 2219        1.36  [Hip Hop, Rap Rock, Pop Rap, Trap, Alternative...
# 2415        1.90                  [Trap, Southern Hip Hop, Pop Rap]
# 2436        1.98         [Pop Rock, Alt-Pop, Electropop, Power Pop]
# 2825        1.65      [Pop, Folk Pop, Pop Rap, Pop Rock, Dance-Pop]
# 2843        0.85  [Trap, West Coast Hip Hop, Cloud Rap, Pop Rap,...
# 3112        2.12                    [Pop Punk, Power Pop, Pop Rock]
# 3146        0.96  [Dance-Pop, Electropop, Pop Rock, Hip House, F...
# 3196        1.92  [Pop Rap, Political Hip Hop, Conscious Hip Hop...
# 3210        1.67                    [Electropop, Pop Rock, Alt-Pop]
# 3326        1.76   [Trap, Southern Hip Hop, Pop Rap, Ratchet Music]
# 3339        1.99                           [Pop Rock, Country Rock]
# 3395        0.62  [Musical Parody, Comedy Rock, Satire, Rock Ope...
# 3415        1.47  [Trap, East Coast Hip Hop, Pop Rap, Reggaetón,...
# 3582        1.24  [Trap, Conscious Hip Hop, Pop Rap, Hardcore Hi...
# 3655        1.88                            [Hard Rock, Blues Rock]
# 3699        1.00  [Indie Pop, Pop Rock, Soundtracks, Pop Rap, Al...
# 3705        1.95                 [Post-Grunge, Hard Rock, Pop Rock]
# 3757        1.90  [Pop Punk, Alternative Rock, Power Pop, Garage...
# 3798        1.54                   [Pop Rock, Electropop, Synthpop]
# 3977        1.66                  [Punk Rock, New Wave, Synth Punk]
# 3984        1.89         [Pop Punk, Pop Rock, Power Pop, Power Pop]
# 4039        1.98  [East Coast Hip Hop, Conscious Hip Hop, Gangst...
# 4077        1.96       [Post-Grunge, Hard Rock, Pop Rock, Pop Rock]
# 4139        1.89  [Pop Rap, Electropop, Dance-Pop, Dance-Pop, Hi...
# 4169        2.05  [Neo-Psychedelia, Psychedelic Pop, Alternative...
# 4254        1.97          [Pop Rock, Electropop, Alternative Dance]
# 4412        1.72  [Rap Rock, Nu Metal, Rap Metal, Alternative Rock]
# 4488        2.11             [Heavy Metal, Hard Rock, Thrash Metal]
# 4549        0.93              [Singer-Songwriter, Indie Folk, Trap]
# 4611        1.20                    [Electropop, Pop Rock, Alt-Pop]
# 4637        1.54       [Pop Rap, Trap, Contemporary R&B, Cloud Rap]
# 4764        1.45                    [Electropop, Pop Rock, Alt-Pop]
# 4765        1.93        [Electropop, Pop Rock, Dance-Pop, Big Band]
# 4832        2.08  [Pop Rock, Pop, Synthpop, Piano Rock, Space Am...
# 4895        1.85                                [Nu Metal, Brostep]
# 4947        1.76                      [Power Pop, Alternative Rock]
#
#      release_date
# 391    2003-06-05
# 862    2017-08-25
# 922    2017-12-15
# 942    2018-06-29
# 945    2018-08-31
# 1119   2021-09-03
# 1141   2018-03-16
# 1280   2011-11-01
# 1427   2020-01-17
# 1463   2019-07-26
# 1549   2009-10-30
# 1795   2015-12-04
# 1922   2020-02-07
# 1924   2019-01-24
# 2201   2019-03-01
# 2219   2018-12-07
# 2415   2018-01-26
# 2436   2017-10-27
# 2825   2017-03-03
# 2843   2018-04-06
# 3112   2012-09-25
# 3146   2016-06-15
# 3196   2017-05-05
# 3210   2017-05-19
# 3326   2019-02-22
# 3339   1973-02-01
# 3395   2019-09-15
# 3415   2018-11-27
# 3582   2019-05-10
# 3655   2018-10-19
# 3699   2019-03-26
# 3705   2001-09-11
# 3757   2012-11-13
# 3798   2017-06-23
# 3977   1985-11-04
# 3984   2012-12-11
# 4039   1999-11-23
# 4077   2005-10-04
# 4139   2009-06-09
# 4169   2015-08-30
# 4254   2015-01-20
# 4412   2003-09-23
# 4488   2013-06-04
# 4549   2019-12-06
# 4611   2018-11-09
# 4637   2017-05-26
# 4764   2018-01-19
# 4765   2018-06-22
# 4832   2021-10-15
# 4895   2011-12-06
# 4947   2010-11-02

# %%
df_g.loc[df_g['avg_rating'] >= df_g['avg_rating'].quantile(0.99), preview_columns + ['release_date']]
# Out:
#                                           release_name  \
# 1                                          OK Computer
# 2                                                Kid A
# 3                            The Dark Side of the Moon
# 4                                             Loveless
# 6                                          In Rainbows
# 7                                   Wish You Were Here
# 10                                 To Pimp a Butterfly
# 11                       The Velvet Underground & Nico
# 12                    In the Court of the Crimson King
# 13                                          Abbey Road
# 14               Sgt. Pepper's Lonely Hearts Club Band
# 16                                            Revolver
# 17                              good kid, m.A.A.d city
# 18   The Rise and Fall of Ziggy Stardust and the Sp...
# 23                                         Madvillainy
# 26                                     Remain in Light
# 27                                             Animals
# 29                                          Pet Sounds
# 30                                            Paranoid
# 31                           The Beatles [White Album]
# 32                                   The Queen Is Dead
# 33      Lift Yr. Skinny Fists Like Antennas to Heaven!
# 36                                           Doolittle
# 40                                          Spiderland
# 45                                            Illmatic
# 52                                               Dummy
# 53                                        Kind of Blue
# 54                                           Pink Moon
# 56                                      Disintegration
# 60                                                 Low
# 69                     Enter the Wu-Tang (36 Chambers)
# 77                                   Endtroducing.....
# 78                                               F♯A♯∞
# 84                                Highway 61 Revisited
# 87                                        Marquee Moon
# 88                                      A Love Supreme
# 91                                      The Glow Pt. 2
# 92                                  The Low End Theory
# 93                                   Master of Reality
# 100                                         Vespertine
# 101                                                Red
# 103                                     Hounds of Love
# 105                                Are You Experienced
# 117                                        Long Season
# 120                                   Blonde on Blonde
# 123                                  Close to the Edge
# 143                The Black Saint and the Sinner Lady
# 156                                  Electric Ladyland
# 169                                Blood on the Tracks
# 172                                       Bitches Brew
# 174                                    What's Going On
# 210                          Soundtracks for the Blind
# 223                                    In a Silent Way
# 230                             Songs of Leonard Cohen
# 425                           Songs in the Key of Life
#
#                        artist_name  avg_rating  \
# 1                        Radiohead        4.24
# 2                        Radiohead        4.23
# 3                       Pink Floyd        4.21
# 4              My Bloody Valentine        4.24
# 6                        Radiohead        4.20
# 7                       Pink Floyd        4.30
# 10                  Kendrick Lamar        4.30
# 11   The Velvet Underground & Nico        4.23
# 12                    King Crimson        4.30
# 13                     The Beatles        4.25
# 14                     The Beatles        4.13
# 16                     The Beatles        4.23
# 17                  Kendrick Lamar        4.22
# 18                     David Bowie        4.26
# 23                      Madvillain        4.28
# 26                   Talking Heads        4.25
# 27                      Pink Floyd        4.14
# 29                  The Beach Boys        4.18
# 30                   Black Sabbath        4.20
# 31                     The Beatles        4.14
# 32                      The Smiths        4.13
# 33     Godspeed You Black Emperor!        4.18
# 36                          Pixies        4.12
# 40                           Slint        4.15
# 45                             Nas        4.21
# 52                      Portishead        4.12
# 53                     Miles Davis        4.23
# 54                      Nick Drake        4.18
# 56                        The Cure        4.18
# 60                     David Bowie        4.13
# 69                    Wu-Tang Clan        4.20
# 77                       DJ Shadow        4.12
# 78     Godspeed You Black Emperor!        4.13
# 84                       Bob Dylan        4.17
# 87                      Television        4.13
# 88                   John Coltrane        4.30
# 91                 The Microphones        4.12
# 92            A Tribe Called Quest        4.12
# 93                   Black Sabbath        4.12
# 100                          Björk        4.15
# 101                   King Crimson        4.22
# 103                      Kate Bush        4.15
# 105    The Jimi Hendrix Experience        4.12
# 117                       Fishmans        4.17
# 120                      Bob Dylan        4.15
# 123                            Yes        4.14
# 143                         Mingus        4.34
# 156    The Jimi Hendrix Experience        4.15
# 169                      Bob Dylan        4.16
# 172                    Miles Davis        4.16
# 174                    Marvin Gaye        4.12
# 210                          Swans        4.12
# 223                    Miles Davis        4.21
# 230                  Leonard Cohen        4.13
# 425                  Stevie Wonder        4.20
#
#                                                 genres release_date
# 1                         [Alternative Rock, Art Rock]   1997-06-16
# 2    [Art Rock, Experimental Rock, Electronic, Ambi...   2000-10-03
# 3    [Art Rock, Progressive Rock, Psychedelic Rock,...   1973-03-23
# 4    [Shoegaze, Noise Pop, Dream Pop, Neo-Psychedelia]   1991-11-11
# 6    [Art Rock, Alternative Rock, Electronic, Dream...   2007-10-10
# 7    [Progressive Rock, Art Rock, Space Rock, Psych...   1975-09-12
# 10   [Conscious Hip Hop, West Coast Hip Hop, Jazz R...   2015-03-15
# 11   [Art Rock, Experimental Rock, Proto-Punk, Nois...   1967-03-12
# 12   [Progressive Rock, Art Rock, Symphonic Prog, J...   1969-10-10
# 13        [Pop Rock, Psychedelic Pop, Progressive Pop]   1969-09-26
# 14   [Psychedelic Pop, Pop Rock, Art Rock, Psychede...   1967-06-01
# 16   [Pop Rock, Psychedelic Pop, Psychedelic Rock, ...   1966-08-05
# 17   [West Coast Hip Hop, Conscious Hip Hop, Hardco...   2012-10-22
# 18         [Glam Rock, Pop Rock, Art Rock, Rock Opera]   1972-06-16
# 23   [Abstract Hip Hop, Jazz Rap, Experimental Hip ...   2004-03-23
# 26   [New Wave, Post-Punk, Funk, Afrobeat, Experime...   1980-10-08
# 27      [Progressive Rock, Art Rock, Psychedelic Rock]   1977-01-21
# 29   [Baroque Pop, Sunshine Pop, Psychedelic Pop, P...   1966-05-16
# 30   [Heavy Metal, Hard Rock, Traditional Doom Meta...   1970-09-18
# 31   [Pop Rock, Rock, Psychedelic Rock, Blues Rock,...   1968-11-22
# 32                  [Jangle Pop, Indie Pop, Post-Punk]   1986-06-16
# 33   [Post-Rock, Field Recordings, Drone, Chamber M...   2000-10-09
# 36   [Alternative Rock, Indie Rock, Surf Rock, Nois...   1989-04-17
# 40   [Post-Rock, Post-Hardcore, Math Rock, Experime...   1991-03-27
# 45   [East Coast Hip Hop, Boom Bap, Hardcore Hip Ho...   1994-04-19
# 52                    [Trip Hop, Acid Jazz, Dark Jazz]   1994-08-22
# 53                             [Modal Jazz, Cool Jazz]   1959-08-17
# 54   [Contemporary Folk, Singer-Songwriter, Folk Ba...   1972-02-25
# 56                 [Gothic Rock, Post-Punk, Dream Pop]   1989-05-02
# 60   [Art Rock, Ambient, Electronic, Art Pop, Kraut...   1977-01-14
# 69    [East Coast Hip Hop, Boom Bap, Hardcore Hip Hop]   1993-11-09
# 77   [Instrumental Hip Hop, Experimental Hip Hop, P...   1996-11-19
# 78   [Post-Rock, Field Recordings, Spoken Word, Amb...   1997-08-14
# 84   [Folk Rock, Singer-Songwriter, Blues Rock, Con...   1965-08-30
# 87                     [Art Punk, Art Rock, Post-Punk]   1977-02-08
# 88              [Spiritual Jazz, Modal Jazz, Post-Bop]   1965-02-01
# 91   [Indie Folk, Psychedelic Folk, Lo-Fi/Slacker R...   2001-09-11
# 92   [Jazz Rap, East Coast Hip Hop, Conscious Hip H...   1991-09-24
# 93   [Heavy Metal, Traditional Doom Metal, Doom Metal]   1971-07-21
# 100  [Art Pop, Electronic, Ambient Pop, Glitch Pop,...   2001-08-27
# 101  [Progressive Rock, Art Rock, Jazz-Rock, Hard R...   1974-10-06
# 103  [Art Pop, Progressive Pop, Synthpop, Baroque Pop]   1985-09-16
# 105  [Blues Rock, Psychedelic Rock, Acid Rock, Hard...   1967-05-12
# 117  [Dream Pop, Neo-Psychedelia, Progressive Pop, ...   1996-10-25
# 120         [Folk Rock, Singer-Songwriter, Blues Rock]   1966-06-20
# 123                 [Symphonic Prog, Progressive Rock]   1972-09-08
# 143  [Avant-Garde Jazz, Third Stream, Experimental ...   1963-07-01
# 156  [Blues Rock, Psychedelic Rock, Acid Rock, Hard...   1968-10-25
# 169  [Singer-Songwriter, Folk Rock, Contemporary Folk]   1975-01-20
# 172  [Jazz Fusion, Avant-Garde Jazz, Jazz-Rock, Jaz...   1970-03-30
# 174                                [Soul, Smooth Soul]   1971-05-21
# 210  [Experimental Rock, Post-Rock, Experimental, D...   1996-10-22
# 223        [Jazz Fusion, Modal Jazz, Avant-Garde Jazz]   1969-07-30
# 230  [Contemporary Folk, Singer-Songwriter, Chamber...   1967-12-27
# 425                [Soul, Funk, Smooth Soul, Pop Soul]   1976-09-28
